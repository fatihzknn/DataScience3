# %%
import pandas as pd

# %%
pika = pd.read_csv("Pokemon.csv",index_col="Name")

# %%
pika.head()
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
len(pika)
# Out:
# 800

# %%
pika.shape
# Out:
# (800, 12)

# %%
pika.dtypes
# Out:
# #              int64
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
pika.iloc[200]
# Out:
# #               185
# Type 1         Rock
# Type 2          NaN
# Total           410
# HP               70
# Attack          100
# Defense         115
# Sp. Atk          30
# Sp. Def          65
# Speed            30
# Generation        2
# Legendary     False
# Name: Sudowoodo, dtype: object

# %%
pika.loc["Pikachu"]
# Out:
# #                   25
# Type 1        Electric
# Type 2             NaN
# Total              320
# HP                  35
# Attack              55
# Defense             40
# Sp. Atk             50
# Sp. Def             50
# Speed               90
# Generation           1
# Legendary        False
# Name: Pikachu, dtype: object

# %%
pika.head()
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
pika.sort_values(by = "Attack",ascending=False ).head()
# Out:
#                            #   Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# MewtwoMega Mewtwo X      150  Psychic  Fighting    780  106     190      100
# HeracrossMega Heracross  214      Bug  Fighting    600   80     185      115
# GroudonPrimal Groudon    383   Ground      Fire    770  100     180      160
# RayquazaMega Rayquaza    384   Dragon    Flying    780  105     180      100
# DeoxysAttack Forme       386  Psychic       NaN    600   50     180       20
#
#                          Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# MewtwoMega Mewtwo X          154      100    130           1       True
# HeracrossMega Heracross       40      105     75           2      False
# GroudonPrimal Groudon        150       90     90           3       True
# RayquazaMega Rayquaza        180      100    115           3       True
# DeoxysAttack Forme           180       20    150           3       True

# %%
pika.sort_values(by = ["Attack","HP"],ascending=False ).head()
# Out:
#                            #   Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# MewtwoMega Mewtwo X      150  Psychic  Fighting    780  106     190      100
# HeracrossMega Heracross  214      Bug  Fighting    600   80     185      115
# RayquazaMega Rayquaza    384   Dragon    Flying    780  105     180      100
# GroudonPrimal Groudon    383   Ground      Fire    770  100     180      160
# DeoxysAttack Forme       386  Psychic       NaN    600   50     180       20
#
#                          Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# MewtwoMega Mewtwo X          154      100    130           1       True
# HeracrossMega Heracross       40      105     75           2      False
# RayquazaMega Rayquaza        180      100    115           3       True
# GroudonPrimal Groudon        150       90     90           3       True
# DeoxysAttack Forme           180       20    150           3       True

# %%
pika.sort_index().head()
# Out:
#                            #   Type 1 Type 2  Total  HP  Attack  Defense  \
# Name
# Abomasnow                460    Grass    Ice    494  90      92       75
# AbomasnowMega Abomasnow  460    Grass    Ice    594  90     132      105
# Abra                      63  Psychic    NaN    310  25      20       15
# Absol                    359     Dark    NaN    465  65     130       60
# AbsolMega Absol          359     Dark    NaN    565  65     150       60
#
#                          Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Abomasnow                     92       85     60           4      False
# AbomasnowMega Abomasnow      132      105     30           4      False
# Abra                         105       55     90           1      False
# Absol                         75       60     75           3      False
# AbsolMega Absol              115       60    115           3      False

# %%
pika.loc["Kadabra"]
# Out:
# #                  64
# Type 1        Psychic
# Type 2            NaN
# Total             400
# HP                 40
# Attack             35
# Defense            30
# Sp. Atk           120
# Sp. Def            70
# Speed             105
# Generation          1
# Legendary       False
# Name: Kadabra, dtype: object

# %%
pika["Type 1"].head(10)
# Out:
# Name
# Bulbasaur                    Grass
# Ivysaur                      Grass
# Venusaur                     Grass
# VenusaurMega Venusaur        Grass
# Charmander                    Fire
# Charmeleon                    Fire
# Charizard                     Fire
# CharizardMega Charizard X     Fire
# CharizardMega Charizard Y     Fire
# Squirtle                     Water
# Name: Type 1, dtype: object

# %%
pika[pika["Type 1"] == "Psychic"].head()
# Out:
#                         #   Type 1 Type 2  Total  HP  Attack  Defense  \
# Name
# Abra                   63  Psychic    NaN    310  25      20       15
# Kadabra                64  Psychic    NaN    400  40      35       30
# Alakazam               65  Psychic    NaN    500  55      50       45
# AlakazamMega Alakazam  65  Psychic    NaN    590  55      50       65
# Drowzee                96  Psychic    NaN    328  60      48       45
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Abra                       105       55     90           1      False
# Kadabra                    120       70    105           1      False
# Alakazam                   135       95    120           1      False
# AlakazamMega Alakazam      175       95    150           1      False
# Drowzee                     43       90     42           1      False

# %%
pokemon_psychic_ability = pika[pika["Type 1"] == "Psychic"]

# %%
pokemon_psychic_ability.head()
# Out:
#                         #   Type 1 Type 2  Total  HP  Attack  Defense  \
# Name
# Abra                   63  Psychic    NaN    310  25      20       15
# Kadabra                64  Psychic    NaN    400  40      35       30
# Alakazam               65  Psychic    NaN    500  55      50       45
# AlakazamMega Alakazam  65  Psychic    NaN    590  55      50       65
# Drowzee                96  Psychic    NaN    328  60      48       45
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# Abra                       105       55     90           1      False
# Kadabra                    120       70    105           1      False
# Alakazam                   135       95    120           1      False
# AlakazamMega Alakazam      175       95    150           1      False
# Drowzee                     43       90     42           1      False

# %%
pika_in_title = pika.index.str.lower().str.contains("chu")

# %%
pika[pika_in_title]
# Out:
#             #    Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Pikachu    25  Electric      NaN    320  35      55       40       50
# Raichu     26  Electric      NaN    485  60      90       55       90
# Pichu     172  Electric      NaN    205  20      40       15       35
# Smoochum  238       Ice  Psychic    305  45      30       15       85
#
#           Sp. Def  Speed  Generation  Legendary
# Name
# Pikachu        50     90           1      False
# Raichu         80    110           1      False
# Pichu          35     60           2      False
# Smoochum       65     65           2      False

# %%
types = pika.groupby("Type 1")

# %%
(types["Attack"].sum()/len(types["Attack"])).max()
# Out:
# 461.3888888888889
