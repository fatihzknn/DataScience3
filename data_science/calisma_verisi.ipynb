# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
market = pd.read_csv("supermarket_sales - Sheet1.csv")

# %%
market.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
market.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %% [markdown]
# market.groupby("City").mean()

# %%
market["Invoice ID"] = "InvoiceID"

# %%
market.head()
# Out:
#   Invoice ID Branch       City Customer type  Gender            Product line  \
# 0  InvoiceID      A     Yangon        Member  Female       Health and beauty
# 1  InvoiceID      C  Naypyitaw        Normal  Female  Electronic accessories
# 2  InvoiceID      A     Yangon        Normal    Male      Home and lifestyle
# 3  InvoiceID      A     Yangon        Member    Male       Health and beauty
# 4  InvoiceID      A     Yangon        Normal    Male       Sports and travel
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1       15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2       46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3       58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4       86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating
# ...

# %%
market.tail()
# Out:
#     Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  InvoiceID      C  Naypyitaw        Normal    Male    Health and beauty
# 996  InvoiceID      B   Mandalay        Normal  Female   Home and lifestyle
# 997  InvoiceID      A     Yangon        Member    Male   Food and beverages
# 998  InvoiceID      A     Yangon        Normal    Male   Home and lifestyle
# 999  InvoiceID      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %%
market = pd.read_csv("supermarket_sales - Sheet1.csv")
market.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
market["Invoice ID"].rename("InvoiceID")
# Out:
# 0      750-67-8428
# 1      226-31-3081
# 2      631-41-3108
# 3      123-19-1176
# 4      373-73-7910
#           ...
# 995    233-67-5758
# 996    303-96-2227
# 997    727-02-1313
# 998    347-56-2442
# 999    849-09-3807
# Name: InvoiceID, Length: 1000, dtype: object

# %%
market.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
market.rename(columns = {"Invoice ID":"InvoiceID",
                         "Product line":"ProductLine",
                         "Customer type":"CustomerType",
                         "Unit price":"UnitPrice",
                         "gross margin percentage":"GrossMarginPercentage",
                         "gross income":"GrossIncome"}, inplace = True)

# %%
market.head()
# Out:
#      InvoiceID Branch       City CustomerType  Gender             ProductLine  \
# 0  750-67-8428      A     Yangon       Member  Female       Health and beauty
# 1  226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 2  631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 3  123-19-1176      A     Yangon       Member    Male       Health and beauty
# 4  373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#    UnitPrice  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0      74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1      15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2      46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3      58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4      86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  GrossMarginPercentage  GrossIncome  Rating
# ...

# %%
pokemon = pd.read_csv("Pokemon.csv")

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon.dropna(axis= 0,thresh = 0)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
esik = sum(pokemon.Speed)/len(pokemon.Speed)
pokemon["hız_seviyesi"] = ["high" if i > esik else "low" for i in pokemon.Speed]
pokemon.loc[:10,["hız_seviyesi","Speed"]]
# Out:
#    hız_seviyesi  Speed
# 0           low     45
# 1           low     60
# 2          high     80
# 3          high     80
# 4           low     65
# 5          high     80
# 6          high    100
# 7          high    100
# 8          high    100
# 9           low     43
# 10          low     58

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   #             800 non-null    int64
#  1   Name          800 non-null    object
#  2   Type 1        800 non-null    object
#  3   Type 2        414 non-null    object
#  4   Total         800 non-null    int64
#  5   HP            800 non-null    int64
#  6   Attack        800 non-null    int64
#  7   Defense       800 non-null    int64
#  8   Sp. Atk       800 non-null    int64
#  9   Sp. Def       800 non-null    int64
#  10  Speed         800 non-null    int64
#  11  Generation    800 non-null    int64
#  12  Legendary     800 non-null    bool
#  13  hız_seviyesi  800 non-null    object
# dtypes: bool(1), int64(9), object(4)
# memory usage: 82.2+ KB

# %%
print(pokemon['Type 1'].value_counts(dropna =False))
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Dragon       32
# Ground       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
pokemon.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
pokemon.boxplot(column='Attack',by = 'Legendary')

# %%
yeni_veri = pokemon.head()

# %%
yeni_veri
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary hız_seviyesi
# 0       65       65     45           1      False          low
# 1       80       80     60           1      False          low
# 2      100      100     80           1      False         high
# 3      122      120     80           1      False         high
# 4       60       50     65           1      False          low

# %%
meltlenmis = pd.melt(frame=yeni_veri,id_vars = 'Name', value_vars= ['Attack','Defense'])
meltlenmis
# Out:
#                     Name variable  value
# 0              Bulbasaur   Attack     49
# 1                Ivysaur   Attack     62
# 2               Venusaur   Attack     82
# 3  VenusaurMega Venusaur   Attack    100
# 4             Charmander   Attack     52
# 5              Bulbasaur  Defense     49
# 6                Ivysaur  Defense     63
# 7               Venusaur  Defense     83
# 8  VenusaurMega Venusaur  Defense    123
# 9             Charmander  Defense     43

# %%
meltlenmis.pivot(index = "Name", columns= "variable",values="value")
# Out:
# variable               Attack  Defense
# Name
# Bulbasaur                  49       49
# Charmander                 52       43
# Ivysaur                    62       63
# Venusaur                   82       83
# VenusaurMega Venusaur     100      123

# %%
veri1 = pokemon.head()
veri2 = pokemon.tail()

# %%
conc_data_row = pd.concat([veri1,veri2],axis =0,ignore_index =True) # axis = 0 : veri setlerini satır olarak altına ekler.
conc_data_row
# Out:
#      #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1              Bulbasaur    Grass  Poison    318  45      49       49
# 1    2                Ivysaur    Grass  Poison    405  60      62       63
# 2    3               Venusaur    Grass  Poison    525  80      82       83
# 3    3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4    4             Charmander     Fire     NaN    309  39      52       43
# 5  719                Diancie     Rock   Fairy    600  50     100      150
# 6  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 7  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 8  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 9  721              Volcanion     Fire   Water    600  80     110      120
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary hız_seviyesi
# 0       65       65     45           1      False          low
# ...

# %%
veri1 = pokemon['Attack'].head()
veri2= pokemon['Defense'].head()
conc_data_col = pd.concat([veri1,veri2],axis =1) # axis = 0 : veri setlerini sütun olarak ekler
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %%
pokemon['Type 1'] = pokemon['Type 1'].astype('category')

# %%
pokemon.dtypes
# Out:
# #                  int64
# Name              object
# Type 1          category
# Type 2            object
# Total              int64
# HP                 int64
# Attack             int64
# Defense            int64
# Sp. Atk            int64
# Sp. Def            int64
# Speed              int64
# Generation         int64
# Legendary           bool
# hız_seviyesi      object
# dtype: object

# %%
pokemon["Type 2"].value_counts(dropna =False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ghost        14
# Water        14
# Rock         14
# Ice          14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
veri1 = pokemon

# %%
veri1["Type 2"].dropna(inplace = True)

# %%
assert 1== 1

# %%
assert  pokemon['Type 2'].notnull().all()

# %%
veri1.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary hız_seviyesi
# 0       65       65     45           1      False          low
# 1       80       80     60           1      False          low
# 2      100      100     80           1      False         high
# 3      122      120     80           1      False         high
# 4       60       50     65           1      False          low

# %%
pokemon["Type 2"].fillna('empty',inplace = True)

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary hız_seviyesi
# 0       65       65     45           1      False          low
# 1       80       80     60           1      False          low
# 2      100      100     80           1      False         high
# 3      122      120     80           1      False         high
# 4       60       50     65           1      False          low

# %%
assert  pokemon['Type 2'].notnull().all()

# %%
pokemon.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary hız_seviyesi
# 795      100      150     50           6       True          low
# 796      160      110    110           6       True         high
# 797      150      130     70           6       True         high
# 798      170      130     80           6       True         high
# 799      130       90     70           6       True         high

# %%
pokemon["Type 2"].notnull().all()
# Out:
# True

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   #             800 non-null    int64
#  1   Name          800 non-null    object
#  2   Type 1        800 non-null    category
#  3   Type 2        414 non-null    object
#  4   Total         800 non-null    int64
#  5   HP            800 non-null    int64
#  6   Attack        800 non-null    int64
#  7   Defense       800 non-null    int64
#  8   Sp. Atk       800 non-null    int64
#  9   Sp. Def       800 non-null    int64
#  10  Speed         800 non-null    int64
#  11  Generation    800 non-null    int64
#  12  Legendary     800 non-null    bool
#  13  hız_seviyesi  800 non-null    object
# dtypes: bool(1), category(1), int64(9), object(3)
# memory usage: 74.4+ KB

# %%
pokemon["Type 2"].dropna(inplace = True)

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary hız_seviyesi
# 0       65       65     45           1      False          low
# 1       80       80     60           1      False          low
# 2      100      100     80           1      False         high
# 3      122      120     80           1      False         high
# 4       60       50     65           1      False          low

# %%
pokemon1 = pokemon.dropna()

# %%
pokemon1
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6      6              Charizard     Fire  Flying    534  78      84       78
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemon1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   #             414 non-null    int64
#  1   Name          414 non-null    object
#  2   Type 1        414 non-null    category
#  3   Type 2        414 non-null    object
#  4   Total         414 non-null    int64
#  5   HP            414 non-null    int64
#  6   Attack        414 non-null    int64
#  7   Defense       414 non-null    int64
#  8   Sp. Atk       414 non-null    int64
#  9   Sp. Def       414 non-null    int64
#  10  Speed         414 non-null    int64
#  11  Generation    414 non-null    int64
#  12  Legendary     414 non-null    bool
#  13  hız_seviyesi  414 non-null    object
# dtypes: bool(1), category(1), int64(9), object(3)
# memory usage: 43.6+ KB

# %%
pokemon2  = pokemon.dropna(axis = 1)

# %%
pokemon2.head()
# Out:
#    #                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass    318  45      49       49       65
# 1  2                Ivysaur  Grass    405  60      62       63       80
# 2  3               Venusaur  Grass    525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 4  4             Charmander   Fire    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary hız_seviyesi
# 0       65     45           1      False          low
# 1       80     60           1      False          low
# 2      100     80           1      False         high
# 3      120     80           1      False         high
# 4       50     65           1      False          low

# %%
pokemon2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   #             800 non-null    int64
#  1   Name          800 non-null    object
#  2   Type 1        800 non-null    category
#  3   Total         800 non-null    int64
#  4   HP            800 non-null    int64
#  5   Attack        800 non-null    int64
#  6   Defense       800 non-null    int64
#  7   Sp. Atk       800 non-null    int64
#  8   Sp. Def       800 non-null    int64
#  9   Speed         800 non-null    int64
#  10  Generation    800 non-null    int64
#  11  Legendary     800 non-null    bool
#  12  hız_seviyesi  800 non-null    object
# dtypes: bool(1), category(1), int64(9), object(2)
# memory usage: 71.2+ KB

# %%
pokemon1 = pokemon["Type 2"].value_counts(dropna = True)

# %%
pokemon1.head()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Name: Type 2, dtype: int64
